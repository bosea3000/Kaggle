# %%
install.packages('dplyr')
install.packages('cars')
install.packages('heplots')
install.packages('psych')
# Out:
# Warning message in install.packages("dplyr"):
# “installation of package ‘dplyr’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Warning message:
# “package ‘cars’ is not available (for R version 3.3.1)”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Warning message in install.packages("psych"):
# “installation of package ‘psych’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
# Out:
# Error in library(cars): there is no package called ‘cars’
# Traceback:
#
# 1. library(cars)
# 2. stop(txt, domain = NA)

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library('heplots')
# Out:
# Loading required package: car

# %%
library(car)

# %%
library(heplots)

# %%
library(ggplot2)

# %%
library(stats)

# %%
library(psych)
# Out:
# Attaching package: ‘psych’
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha
#
# The following object is masked from ‘package:car’:
#
#     logit

# %%
train <- read.csv('Data/train.csv', header = TRUE)

# %%
summary(train)
# Out:
#        Id           MSSubClass       MSZoning     LotFrontage
#  Min.   :   1.0   Min.   : 20.0   C (all):  10   Min.   : 21.00
#  1st Qu.: 365.8   1st Qu.: 20.0   FV     :  65   1st Qu.: 59.00
#  Median : 730.5   Median : 50.0   RH     :  16   Median : 69.00
#  Mean   : 730.5   Mean   : 56.9   RL     :1151   Mean   : 70.05
#  3rd Qu.:1095.2   3rd Qu.: 70.0   RM     : 218   3rd Qu.: 80.00
#  Max.   :1460.0   Max.   :190.0                  Max.   :313.00
#                                                  NA's   :259
#     LotArea        Street      Alley      LotShape  LandContour  Utilities
#  Min.   :  1300   Grvl:   6   Grvl:  50   IR1:484   Bnk:  63    AllPub:1459
#  1st Qu.:  7554   Pave:1454   Pave:  41   IR2: 41   HLS:  50    NoSeWa:   1
#  Median :  9478               NA's:1369   IR3: 10   Low:  36
#  Mean   : 10517                           Reg:925   Lvl:1311
#  3rd Qu.: 11602
#  Max.   :215245
#
#    LotConfig    LandSlope   Neighborhood   Condition1     Condition2
# ...

# %%
fit.lm <- lm(train$SalePrice ~ ., data = train)
# Out:
# Error in `contrasts<-`(`*tmp*`, value = contr.funs[1 + isOF[nn]]): contrasts can be applied only to factors with 2 or more levels
# Traceback:
#
# 1. lm(train$SalePrice ~ ., data = train)
# 2. model.matrix(mt, mf, contrasts)
# 3. model.matrix.default(mt, mf, contrasts)
# 4. `contrasts<-`(`*tmp*`, value = contr.funs[1 + isOF[nn]])
# 5. stop("contrasts can be applied only to factors with 2 or more levels")

# %%
out <- read.csv('out.csv', header = TRUE)

# %%
summary(out)
# Out:
#        X                Id           MSSubClass        MSZoning
#  Min.   :   0.0   Min.   :   1.0   Min.   : 20.00   C (all):  10
#  1st Qu.: 364.5   1st Qu.: 365.5   1st Qu.: 20.00   FV     :  65
#  Median : 729.0   Median : 730.0   Median : 50.00   RH     :  16
#  Mean   : 729.1   Mean   : 730.1   Mean   : 56.88   RL     :1150
#  3rd Qu.:1093.5   3rd Qu.:1094.5   3rd Qu.: 70.00   RM     : 218
#  Max.   :1459.0   Max.   :1460.0   Max.   :190.00
#
#     LotArea        Street     LotShape  LandContour  Utilities
#  Min.   :  1300   Grvl:   6   IR1:484   Bnk:  63    AllPub:1458
#  1st Qu.:  7549   Pave:1453   IR2: 41   HLS:  50    NoSeWa:   1
#  Median :  9477               IR3: 10   Low:  36
#  Mean   : 10517               Reg:924   Lvl:1310
#  3rd Qu.: 11603
#  Max.   :215245
#
#    LotConfig    LandSlope   Neighborhood   Condition1     Condition2
#  Corner : 263   Gtl:1381   NAmes  :225   Norm   :1259   Norm   :1444
# ...

# %%
fit.mlr <- lm(SalePrice ~ ., data = out)
summary(fit.mlr)
# Out:
# Call:
# lm(formula = SalePrice ~ ., data = out)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -174309  -10535       0    9742  174309
#
# Coefficients: (4 not defined because of singularities)
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -1.199e+06  1.066e+06  -1.125 0.260855
# X                     6.358e-01  1.603e+00   0.397 0.691694
# Id                           NA         NA      NA       NA
# MSSubClass           -7.830e+00  8.553e+01  -0.092 0.927077
# MSZoningFV            3.101e+04  1.225e+04   2.532 0.011470 *
# MSZoningRH            2.371e+04  1.232e+04   1.925 0.054412 .
# MSZoningRL            2.588e+04  1.051e+04   2.463 0.013909 *
# MSZoningRM            2.503e+04  9.852e+03   2.541 0.011174 *
# LotArea               7.006e-01  1.083e-01   6.470 1.40e-10 ***
# StreetPave            3.867e+04  1.229e+04   3.148 0.001685 **
# LotShapeIR2           4.618e+03  4.323e+03   1.068 0.285624
# ...

# %%
library(broom)

# %%
tidyAR <- tidy(fit.mlr)
tidyAR
# Out:
#     term                 estimate      std.error    statistic   p.value
# 1   (Intercept)          -1.198715e+06 1.065643e+06 -1.12487474 2.608550e-01
# 2   X                     6.357653e-01 1.602845e+00  0.39664801 6.916938e-01
# 3   MSSubClass           -7.829712e+00 8.553238e+01 -0.09154091 9.270773e-01
# 4   MSZoningFV            3.100501e+04 1.224650e+04  2.53174393 1.146964e-02
# 5   MSZoningRH            2.371327e+04 1.231648e+04  1.92532887 5.441167e-02
# 6   MSZoningRL            2.587775e+04 1.050653e+04  2.46301562 1.390948e-02
# 7   MSZoningRM            2.503436e+04 9.852409e+03  2.54093754 1.117393e-02
# 8   LotArea               7.006434e-01 1.082966e-01  6.46967288 1.399435e-10
# 9   StreetPave            3.867073e+04 1.228595e+04  3.14755793 1.684774e-03
# 10  LotShapeIR2           4.618151e+03 4.323215e+03  1.06822149 2.856239e-01
# 11  LotShapeIR3           4.584213e+03 9.062795e+03  0.50582775 6.130655e-01
# ...

# %%
etasq(fit.mlr)
# Out:
#               Partial eta^2
# X             1.240616e-04
# Id                      NA
# MSSubClass    6.608582e-06
# MSZoning      5.700861e-03
# LotArea       3.195515e-02
# Street        7.752614e-03
# LotShape      1.048083e-03
# LandContour   8.608963e-03
# Utilities     1.024880e-03
# LotConfig     8.896178e-03
# LandSlope     1.172968e-02
# Neighborhood  1.479625e-01
# Condition1    2.208738e-02
# Condition2    9.760948e-02
# BldgType      1.104647e-02
# HouseStyle    9.442658e-03
# OverallQual   4.654222e-02
# OverallCond   2.951417e-02
# YearBuilt     1.550367e-02
# YearRemodAdd  2.873229e-03
# RoofStyle     7.038136e-03
# RoofMatl      2.663328e-01
# Exterior1st   1.891991e-02
# Exterior2nd   1.277791e-02
# ExterQual     3.559836e-02
# ExterCond     1.512723e-03
# Foundation    7.441362e-03
# BsmtFinSF1    5.254350e-02
# BsmtFinSF2    1.396765e-02
# BsmtUnfSF     1.054176e-02
# ⋮             ⋮
# Electrical    3.939412e-04
# X1stFlrSF     7.736539e-02
# ...

# %%
library(MASS)
# Out:
# Attaching package: ‘MASS’
#
# The following object is masked from ‘package:dplyr’:
#
#     select

# %%
fit <- lm(SalePrice~.,data=out)
step <- stepAIC(fit, direction="both")
step$anova # display results
# Out:
# Start:  AIC=29609.24
# SalePrice ~ X + Id + MSSubClass + MSZoning + LotArea + Street +
#     LotShape + LandContour + Utilities + LotConfig + LandSlope +
#     Neighborhood + Condition1 + Condition2 + BldgType + HouseStyle +
#     OverallQual + OverallCond + YearBuilt + YearRemodAdd + RoofStyle +
#     RoofMatl + Exterior1st + Exterior2nd + ExterQual + ExterCond +
#     Foundation + BsmtFinSF1 + BsmtFinSF2 + BsmtUnfSF + TotalBsmtSF +
#     Heating + HeatingQC + CentralAir + Electrical + X1stFlrSF +
#     X2ndFlrSF + LowQualFinSF + GrLivArea + BsmtFullBath + BsmtHalfBath +
#     FullBath + HalfBath + BedroomAbvGr + KitchenAbvGr + KitchenQual +
#     TotRmsAbvGrd + Functional + Fireplaces + GarageCars + GarageArea +
#     PavedDrive + WoodDeckSF + OpenPorchSF + EnclosedPorch + X3SsnPorch +
#     ScreenPorch + PoolArea + MiscVal + MoSold + YrSold + SaleType +
#     SaleCondition
#
#
# Step:  AIC=29609.24
# SalePrice ~ X + Id + MSSubClass + MSZoning + LotArea + Street +
# ...

# %%
install.packages('leaps')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
# All Subsets Regression
library(leaps)
leaps<-regsubsets(SalePrice~.,data=out,nbest=10)
# view results 
summary(leaps)
# plot a table of models showing variables in each model.
# models are ordered by the selection statistic.
plot(leaps,scale="r2")
# plot statistic by subset size 
library(car)
subsets(leaps, statistic="rsq")
# Out:
# Warning message in leaps.setup(x, y, wt = wt, nbest = nbest, nvmax = nvmax, force.in = force.in, :
# “4  linear dependencies found”
# Reordering variables and trying again:
# Error in leaps.exhaustive(a, really.big): Exhaustive search will be S L O W, must specify really.big=T
# Traceback:
#
# 1. regsubsets(SalePrice ~ ., data = out, nbest = 10)
# 2. regsubsets.formula(SalePrice ~ ., data = out, nbest = 10)
# 3. leaps.exhaustive(a, really.big)
# 4. stop("Exhaustive search will be S L O W, must specify really.big=T")

# %%
library(leaps)
leaps<-regsubsets(SalePrice~.,data=out,nbest=10)
# view results 
summary(leaps)
# Out:
# Warning message in leaps.setup(x, y, wt = wt, nbest = nbest, nvmax = nvmax, force.in = force.in, :
# “4  linear dependencies found”
# Reordering variables and trying again:
# Error in leaps.exhaustive(a, really.big): Exhaustive search will be S L O W, must specify really.big=T
# Traceback:
#
# 1. regsubsets(SalePrice ~ ., data = out, nbest = 10)
# 2. regsubsets.formula(SalePrice ~ ., data = out, nbest = 10)
# 3. leaps.exhaustive(a, really.big)
# 4. stop("Exhaustive search will be S L O W, must specify really.big=T")
